# %% [markdown]
# <a href="https://colab.research.google.com/github/A-ArunPrakash/AIML_AP/blob/main/Decision_Tree_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
inputs = df.drop('Survived',axis='columns')
target = df.Survived

# %%
inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())

# %%
inputs.head()
# Out:
#    Pclass  Sex   Age     Fare
# 0       3    1  22.0   7.2500
# 1       1    2  38.0  71.2833
# 2       3    2  26.0   7.9250
# 3       1    2  35.0  53.1000
# 4       3    1  35.0   8.0500

# %%
inputs = df.drop('Survived',axis='columns')  # Features
target = df.Survived                        # Target

# %%
inputs
# Out:
#      Pclass     Sex   Age     Fare
# 0         3    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         3  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         3    male  35.0   8.0500
# ..      ...     ...   ...      ...
# 886       2    male  27.0  13.0000
# 887       1  female  19.0  30.0000
# 888       3  female   NaN  23.4500
# 889       1    male  26.0  30.0000
# 890       3    male  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Fit the classifier with default hyper-parameters
# --- Apply the mapping to the 'Sex' column after re-creating 'inputs' ---
inputs = df.drop('Survived',axis='columns')
inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})
inputs.Age = inputs.Age.fillna(inputs.Age.mean()) # Fill missing ages

clf = DecisionTreeClassifier()
model = clf.fit(inputs, target)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_1 <= 1.50
# |   |--- feature_2 <= 6.50
# |   |   |--- feature_0 <= 2.50
# |   |   |   |--- class: 1
# |   |   |--- feature_0 >  2.50
# |   |   |   |--- feature_3 <= 20.83
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  20.83
# |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |--- class: 0
# |   |--- feature_2 >  6.50
# |   |   |--- feature_0 <= 1.50
# |   |   |   |--- feature_3 <= 26.14
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  26.14
# |   |   |   |   |--- feature_2 <= 53.00
# |   |   |   |   |   |--- feature_3 <= 27.14
# |   |   |   |   |   |   |--- feature_3 <= 26.47
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  26.47
# |   |   |   |   |   |   |   |--- feature_2 <= 46.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 40.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 31.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 28.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  28.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  31.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  40.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  46.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  27.14
# |   |   |   |   |   |   |--- feature_3 <= 387.66
# |   |   |   |   |   |   |   |--- feature_3 <= 134.64
# |   |   |   |   |   |   |   |   |--- feature_2 <= 27.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 109.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  109.89
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  27.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 115.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 29.10
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  29.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  115.44
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  134.64
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  387.66
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  53.00
# |   |   |   |   |   |--- feature_2 <= 75.50
# |   |   |   |   |   |   |--- feature_3 <= 35.08
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  35.08
# |   |   |   |   |   |   |   |--- feature_3 <= 42.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  42.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 78.24
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  78.24
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 96.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  96.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  75.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_0 >  1.50
# |   |   |   |--- feature_3 <= 51.70
# |   |   |   |   |--- feature_2 <= 13.00
# |   |   |   |   |   |--- feature_3 <= 17.34
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  17.34
# |   |   |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |   |   |--- feature_3 <= 24.21
# |   |   |   |   |   |   |   |   |--- feature_3 <= 19.66
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  19.66
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  24.21
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  13.00
# |   |   |   |   |   |--- feature_2 <= 32.25
# |   |   |   |   |   |   |--- feature_2 <= 30.75
# |   |   |   |   |   |   |   |--- feature_3 <= 23.35
# |   |   |   |   |   |   |   |   |--- feature_3 <= 22.89
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.37
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_3 >  22.89
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  23.35
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  30.75
# |   |   |   |   |   |   |   |--- feature_3 <= 7.81
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  7.81
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.88
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 26.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 20.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  20.93
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  26.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  32.25
# |   |   |   |   |   |   |--- feature_3 <= 7.91
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  7.91
# |   |   |   |   |   |   |   |--- feature_3 <= 7.99
# |   |   |   |   |   |   |   |   |--- feature_2 <= 38.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  38.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 41.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  41.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  7.99
# |   |   |   |   |   |   |   |   |--- feature_2 <= 61.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 13.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 12.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  12.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  13.25
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  61.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 64.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  64.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  51.70
# |   |   |   |   |--- feature_3 <= 63.02
# |   |   |   |   |   |--- feature_2 <= 30.85
# |   |   |   |   |   |   |--- feature_2 <= 27.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  27.00
# |   |   |   |   |   |   |   |--- feature_2 <= 28.85
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  28.85
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  30.85
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  63.02
# |   |   |   |   |   |--- class: 0
# |--- feature_1 >  1.50
# |   |--- feature_0 <= 2.50
# |   |   |--- feature_2 <= 2.50
# |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |--- class: 1
# |   |   |--- feature_2 >  2.50
# |   |   |   |--- feature_3 <= 28.86
# |   |   |   |   |--- feature_3 <= 28.23
# |   |   |   |   |   |--- feature_2 <= 56.00
# |   |   |   |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |   |   |   |--- feature_2 <= 27.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 13.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  13.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 17.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  17.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  27.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 37.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  37.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 39.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  39.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 25.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  25.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- feature_2 >  56.00
# |   |   |   |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  28.23
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  28.86
# |   |   |   |   |--- feature_3 <= 149.04
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  149.04
# |   |   |   |   |   |--- feature_3 <= 152.51
# |   |   |   |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  152.51
# |   |   |   |   |   |   |--- class: 1
# |   |--- feature_0 >  2.50
# |   |   |--- feature_3 <= 23.35
# |   |   |   |--- feature_2 <= 36.50
# |   |   |   |   |--- feature_3 <= 7.89
# |   |   |   |   |   |--- feature_2 <= 30.10
# |   |   |   |   |   |   |--- feature_3 <= 6.99
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  6.99
# |   |   |   |   |   |   |   |--- feature_3 <= 7.52
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  7.52
# |   |   |   |   |   |   |   |   |--- feature_2 <= 15.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  15.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.64
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 26.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  26.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.64
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  30.10
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  7.89
# |   |   |   |   |   |--- feature_3 <= 10.82
# |   |   |   |   |   |   |--- feature_2 <= 19.00
# |   |   |   |   |   |   |   |--- feature_3 <= 10.15
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  10.15
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  19.00
# |   |   |   |   |   |   |   |--- feature_2 <= 30.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.99
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 27.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  27.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.99
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  30.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  10.82
# |   |   |   |   |   |   |--- feature_3 <= 13.91
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  13.91
# |   |   |   |   |   |   |   |--- feature_3 <= 15.37
# |   |   |   |   |   |   |   |   |--- feature_2 <= 29.35
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 16.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  16.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  29.35
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  15.37
# |   |   |   |   |   |   |   |   |--- feature_2 <= 29.35
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 20.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  20.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_2 >  29.35
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 30.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  30.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  36.50
# |   |   |   |   |--- feature_2 <= 55.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  55.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_3 >  23.35
# |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |--- feature_3 <= 31.33
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  31.33
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |--- feature_3 <= 24.81
# |   |   |   |   |   |--- feature_2 <= 19.85
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  19.85
# |   |   |   |   |   |   |--- feature_2 <= 29.85
# |   |   |   |   |   |   |   |--- feature_3 <= 23.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  23.80
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  29.85
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  24.81
# |   |   |   |   |   |--- feature_2 <= 33.85
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  33.85
# |   |   |   |   |   |   |--- feature_2 <= 38.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  38.50
# |   |   |   |   |   |   |   |--- class: 0

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf,
                   feature_names=inputs.columns, # Use inputs.columns instead of inputs.feature_names
                   class_names=['Died', 'Survived'], # Assuming 'Survived' column has 0 and 1
                   filled=True)

# %%
# Assuming you want 'target_names' to represent the labels of your target variable
target_names = ['Died', 'Survived']  # Define target_names before using it
print(target_names)
# Out:
# ['Died', 'Survived']

# %%
print(inputs.columns)  # Print the column names of the 'inputs' DataFrame
# Out:
# Index(['Pclass', 'Sex', 'Age', 'Fare'], dtype='object')

# %%
X = inputs
y = target

# %%
# Splitting arrays or matrices into random train and test subsets
from sklearn.model_selection import train_test_split
# i.e. 70 % training dataset and 30 % test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
# creating a RF classifier
from sklearn.ensemble import RandomForestClassifier # Import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)

# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)

# performing predictions on the test dataset
y_pred = clf.predict(X_test)

# metrics are used to find accuracy or error
from sklearn import metrics
print()

# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL: 0.8022388059701493

# %%
print(df.head()) # Replace 'data' with 'df' which is the DataFrame you previously used
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
# predicting which type of flower it is.
clf.predict([[3, 3, 2, 2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# using the feature importance variable
import pandas as pd
feature_imp = pd.Series(clf.feature_importances_, index=inputs.columns).sort_values(ascending=False) # Use 'inputs' instead of 'input'
feature_imp
# Out:
# Fare      0.344756
# Age       0.284495
# Sex       0.259588
# Pclass    0.111161
# dtype: float64
